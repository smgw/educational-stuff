# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
data_0 = []

# %%
data_0.append(0)
data_0.append(1)
#data.append(1)

# %%
def append_ball(d):
    # d: data array with length>=2 
    a=sum(d)/len(d)
    x=np.random.binomial(1,a) # ← 注目
    return x

# %%
ball_to_put = lambda d : np.random.binomial(1,sum(d)/len(d))

# %%
#ball_to_put([1,1,0,0,0,1,1])

# %%
results=[[] for i in range(10)]
for j in range(10): # 実験は、10回
    data=[1,0]  # 初期状態(一人がA でもう一人がB)
    for k in range(1000): # 千人の市場
        results[j].append(sum(data)/len(data)) # append してるのは、。。。なんでしょう？
        data.append(ball_to_put(data)) # append してるのは。。。。。なんでしょうか？

# %%
#results

# %%
#results[2] # results は、要素10個の配列で、それぞれは 1001 個の数値データのリスト

# %%
fig, ax = plt.subplots(figsize=(14.0,6.0))
for i in range(10):
    plt.plot(results[i])
plt.show()
